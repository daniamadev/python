# %%
import pandas as pd
import lxml

# %%
tables  = pd.read_html("/content/read_html.html")
len(tables)
failures = tables[0]

# %%
failures
# Out:
#    Índice    Banco          Cidade             Estado  Certificado    Empresa  \
# 0       1  Banco A       São Paulo          São Paulo       123456  Empresa X
# 1       2  Banco B  Rio de Janeiro     Rio de Janeiro       789012  Empresa Y
# 2       3  Banco C        Brasília   Distrito Federal       345678  Empresa Z
# 3       4  Banco D        Curitiba             Paraná       567890  Empresa W
# 4       5  Banco E    Porto Alegre  Rio Grande do Sul       901234  Empresa V
# 5       6  Banco F        Salvador              Bahia       234567  Empresa U
# 6       7  Banco G          Recife         Pernambuco       890123  Empresa T
# 7       8  Banco H          Manaus           Amazonas       345678  Empresa S
# 8       9  Banco I           Belém               Pará       678901  Empresa R
# 9      10  Banco J       Fortaleza              Ceará       123456  Empresa Q
#
#   Data de Encerramento Data de Abertura
# 0           2024-12-31       2001-01-01
# ...

# %%
data_encerramento = pd.to_datetime(failures["Data de Encerramento"])
data_encerramento
# Out:
# 0   2024-12-31
# 1   2024-06-30
# 2   2023-03-31
# 3   2022-01-31
# 4   2021-09-30
# 5   2020-05-15
# 6   2019-11-30
# 7   2018-08-31
# 8   2017-04-30
# 9   2016-12-31
# Name: Data de Encerramento, dtype: datetime64[ns]

# %%
data_encerramento.dt.year.value_counts()
# Out:
# Data de Encerramento
# 2024    2
# 2023    1
# 2022    1
# 2021    1
# 2020    1
# 2019    1
# 2018    1
# 2017    1
# 2016    1
# Name: count, dtype: int64
